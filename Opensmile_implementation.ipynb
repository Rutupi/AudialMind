# %%
import opensmile

smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)
features = smile.process_file("OSR_us_000_0010_8k.wav")
print(features.shape)  # (1, 88)
# Out:
# (1, 88)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

X_scaled = StandardScaler().fit_transform(features)
svm = SVC(kernel="rbf", C=1.0, gamma="scale")
uar = cross_val_score(
    svm, X_scaled, y, cv=10,
    scoring="balanced_accuracy"
)
print(f"UAR: {uar.mean():.3f} ± {uar.std():.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16112\1006695792.py in <cell line: 0>()
#       6 svm = SVC(kernel="rbf", C=1.0, gamma="scale")
#       7 uar = cross_val_score(
# ----> 8     svm, X_scaled, y, cv=10,
#       9     scoring="balanced_accuracy"
#      10 )
#
# NameError: name 'y' is not defined
